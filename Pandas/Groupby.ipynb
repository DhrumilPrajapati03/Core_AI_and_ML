# %%
import pandas as pd

df = pd.read_csv('D:\\AI\\Python\\new_batch\\IPLDataSet.csv')
print(df.head(10))
# Out:
#    id  season        city       date                  team1  \
# 0   1    2008   Bangalore  4/18/2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  4/19/2008    Chennai Super Kings
# 2   3    2008       Delhi  4/19/2008       Rajasthan Royals
# 3   4    2008      Mumbai  4/20/2008         Mumbai Indians
# 4   5    2008     Kolkata  4/20/2008        Deccan Chargers
# 5   6    2008      Jaipur  4/21/2008        Kings XI Punjab
# 6   7    2008   Hyderabad  4/22/2008        Deccan Chargers
# 7   8    2008     Chennai  4/23/2008    Chennai Super Kings
# 8   9    2008   Hyderabad  4/24/2008        Deccan Chargers
# 9  10    2008  Chandigarh  4/25/2008        Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# ...

# %%
k = df.groupby(['city','season'])
for i in k:
    print(i)
# Out:
# (('Abu Dhabi', 2014),       id  season       city       date                        team1  \
# 398  399    2014  Abu Dhabi  4/16/2014        Kolkata Knight Riders
# 400  401    2014  Abu Dhabi  4/18/2014          Chennai Super Kings
# 401  402    2014  Abu Dhabi  4/18/2014          Sunrisers Hyderabad
# 405  406    2014  Abu Dhabi  4/21/2014          Chennai Super Kings
# 411  412    2014  Abu Dhabi  4/26/2014  Royal Challengers Bangalore
# 412  413    2014  Abu Dhabi  4/26/2014              Kings XI Punjab
# 416  417    2014  Abu Dhabi  4/29/2014             Rajasthan Royals
#
#                      team2            toss_winner toss_decision  result  \
# 398         Mumbai Indians  Kolkata Knight Riders           bat  normal
# 400        Kings XI Punjab    Chennai Super Kings           bat  normal
# 401       Rajasthan Royals       Rajasthan Royals         field  normal
# 405       Delhi Daredevils    Chennai Super Kings           bat  normal
# ...

# %%
team = df.groupby('team1')
print(team.first())
# Out:
#                               id  season        city       date  \
# team1
# Chennai Super Kings            2    2008  Chandigarh  4/19/2008
# Deccan Chargers                5    2008     Kolkata  4/20/2008
# Delhi Daredevils              14    2008  Chandigarh  4/27/2008
# Gujarat Lions                532    2016      Rajkot  4/21/2016
# Kings XI Punjab                6    2008      Jaipur  4/21/2008
# Kochi Tuskers Kerala         178    2011       Kochi   4/9/2011
# Kolkata Knight Riders          1    2008   Bangalore  4/18/2008
# Mumbai Indians                 4    2008      Mumbai  4/20/2008
# Pune Warriors                191    2011      Mumbai  4/17/2011
# Rajasthan Royals               3    2008       Delhi  4/19/2008
# Rising Pune Supergiants      523    2016      Rajkot  4/14/2016
# Royal Challengers Bangalore   11    2008   Bangalore  4/26/2008
# Sunrisers Hyderabad          325    2013   Hyderabad   4/5/2013
#
#                                                    team2  \
# ...
