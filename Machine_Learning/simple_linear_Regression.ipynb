# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
df = pd.read_csv("D:\Antrix\Core_AI_and_ML\canada_per_capita_income.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\user\AppData\Local\Temp\ipykernel_10820\2462396970.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df = pd.read_csv("D:\Antrix\Core_AI_and_ML\canada_per_capita_income.csv")

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
# sns.scatterplot(x="year", y="per capita income (US$)", data=df)
# plt.show()

import matplotlib.pyplot as plt
plt.scatter(x="year",y="per capita income (US$)", data=df)
plt.show()

# %%
x = df[['year']]
y = df['per capita income (US$)']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
reg = linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict([[2026]])
# Out:
# d:\Antrix\Core_AI_and_ML\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([47417.01608686])

# %%
reg.score(x_test,y_test)
# Out:
# 0.8035321413892609

# %%
y_pred = reg.predict(x)

# %%
sns.scatterplot(x="year", y="per capita income (US$)", data=df)
plt.plot(df["year"], y_pred)
plt.show()
